# %% [markdown]
# ![sc1.png](attachment:4d30ae7a-ffd4-437a-afbc-d0a5e3820d3d.png)

# %%
money = True

if money: 
    print("택시를 타고 가라")
else:
    print("걸어 가라")

if 1+1==3:
    print('correct')
else:
    print('wrong')
# Out:
# 택시를 타고 가라
# wrong

# %% [markdown]
# ![sc2.png](attachment:624dbc97-4595-408e-8743-254b089b3638.png)

# %% [markdown]
# ![sc3.png](attachment:14b3e65e-b84c-459d-b28a-29a7e6f823f2.png)
# ![sc4.png](attachment:25c79578-1b55-4e11-9bcf-7c5e45d9c693.png)

# %%
# indent_error.py
money = True
if money:
    print("택시를")
print("타고")
    print("가라")
# Out:
#   Cell In[62], line 6
#     print("가라")
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ![sc5.png](attachment:1fe4ebf8-7c86-414c-894c-fd7aabe6bb00.png)

# %%
# indent_error2.py
money = True
if money:
         print("택시를")
         print("타고")
              print("가라")
# Out:
# 택시를
# 타고
# 가라

# %% [markdown]
# ![sc6.png](attachment:f8c8c9e8-fc33-41fc-8740-c68df9c55a92.png)

# %% [markdown]
# ![스크린샷 2024-04-13 오후 12.59.10.png](attachment:599aeaab-8e94-4ee2-9680-1c62e447b44a.png)
#
# ![스크린샷 2024-04-13 오후 12.59.59.png](attachment:8a6a4432-7a3a-4648-9018-f47a54d96f57.png)

# %%
x = 3
y = 2
x > y
# Out:
# True

# %%
x < y
# Out:
# False

# %%
x == y
# Out:
# False

# %%
x != y
# Out:
# True

# %% [markdown]
# ![스크린샷 2024-04-13 오후 1.03.00.png](attachment:83787893-99ce-4850-9f9a-24b08c231ee7.png)

# %%
money = 2000

if money >= 3000:
     print("택시를 타고 가라")
else:
     print("걸어가라")
# Out:
# 걸어가라

# %% [markdown]
# ![스크린샷 2024-04-13 오후 1.05.53.png](attachment:6f015d26-431a-48bc-a63a-e7e3b8aede61.png)

# %%
money = 2000
card = True

if money >= 3000 or card:
     print("택시를 타고 가라")
else:
     print("걸어가라")
# Out:
# 택시를 타고 가라

# %% [markdown]
# ![스크린샷 2024-04-13 오후 1.08.35.png](attachment:47ac2a9a-8299-47b8-98d0-35189e8e05e3.png)

# %%
1 in [1, 2, 3]
# Out:
# True

# %%
1 not in [1, 2, 3]
# Out:
# False

# %%
'a' in ('a', 'b', 'c')
# Out:
# True

# %%
'j' not in 'python'
# Out:
# True

# %% [markdown]
# ![스크린샷 2024-04-13 오후 1.12.57.png](attachment:7392a5ab-21ac-4607-952c-ea82989a3bba.png)

# %%
pocket = ['paper', 'cellphone', 'money']

if 'money' in pocket:
         print("택시를 타고 가라")
else:
         print("걸어가라")
# Out:
# 택시를 타고 가라

# %% [markdown]
# ![스크린샷 2024-04-13 오후 1.18.34.png](attachment:9b15ae22-b1f7-4d0d-ba4e-3a59e86da353.png)

# %%
pocket = ['paper', 'cellphone']
card = True

if 'money' in pocket:
    print("택시를 타고가라")
else:
    if card:
        print("택시를 타고가라")
    else:
        print("걸어가라")
# Out:
# 택시를 타고가라

# %% [markdown]
# ![스크린샷 2024-04-13 오후 1.25.20.png](attachment:20590f86-0261-485b-9cd2-32e40da53224.png)

# %%
pocket = ['paper', 'cellphone']
card = True

if 'money' in pocket:
     print("택시를 타고가라")
elif card: 
     print("택시를 타고가라")
else:
     print("걸어가라")
# Out:
# 택시를 타고가라

# %% [markdown]
# ![스크린샷 2024-04-13 오후 1.23.35.png](attachment:da8f8cda-1c26-49d3-b7d0-7e70382716bb.png)

# %% [markdown]
# ![스크린샷 2024-04-13 오후 1.31.47.png](attachment:09bea139-093a-4f87-b9cf-aefc1622e6d7.png)

# %% [markdown]
# ![스크린샷 2024-04-13 오후 1.36.00.png](attachment:7123d913-7ed2-458f-b4b3-36879f8750df.png)

# %%
if score >= 60:
    message = "success"
else:
    message = "failure"

# %% [markdown]
# 파이썬의 조건부 표현식(conditional expression)을 사용하면 위 코드를 다음과 같이 간단히 표현할 수 있다.

# %%
message = "success" if score >= 60 else "failure"

# %% [markdown]
# ![스크린샷 2024-04-13 오후 1.41.18.png](attachment:3bcd44ac-902b-4399-8f72-0cb1810f1974.png)
